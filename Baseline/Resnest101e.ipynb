# %%
# !pip install fastai --upgrade
# !pip install timm wwf
# Out:
# ...
#      |████████████████████████████████| 194kB 16.6MB/s
# ...
#      |████████████████████████████████| 61kB 11.4MB/s
# ...
#   Found existing installation: fastai 1.0.61
#     Uninstalling fastai-1.0.61:
#       Successfully uninstalled fastai-1.0.61
# ...
#      |████████████████████████████████| 245kB 18.0MB/s
# ...
#   Created wheel for wwf: filename=wwf-0.0.10-cp36-none-any.whl size=23155 sha256=70aa528da534889169b77919b58cd6ebf80982de2524bc0c2fa1b6b3f58b8e27
#   Stored in directory: /root/.cache/pip/wheels/c7/22/a7/30cb5077503f2c5d1c0af9187090604237d9e075154d833eb5
# Successfully built wwf
# ...

# %%
# !wget https://www.dropbox.com/s/cb3g53z4pbtaqvl/erm.zip?dl=1 -O erm.zip
# Out:
# --2021-02-05 11:34:52--  https://www.dropbox.com/s/cb3g53z4pbtaqvl/erm.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/cb3g53z4pbtaqvl/erm.zip [following]
# --2021-02-05 11:34:52--  https://www.dropbox.com/s/dl/cb3g53z4pbtaqvl/erm.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca374dde80e1d5905474e328fe1.dl.dropboxusercontent.com/cd/0/get/BIUoyb_WgfWRe5jTKE3ogyb60cjLrr8su7SupEvXEcJvj7fqfQsJP815MG7imWAhc2BLeg02EsVzCd83lYUPLz6v2oONw4tBGiYL48Lsp2vFIT6AkWZ-m9nDfg89Lj_xQ6o/file?dl=1# [following]
# ...

# %%
# !unzip erm.zip
# Out:
# Archive:  erm.zip
#    creating: dataset/
#    creating: dataset/test/
#    creating: dataset/test/no/
#   inflating: dataset/test/no/anonymized_1421704.jpg
#   inflating: dataset/test/no/anonymized_336537.jpg
#   inflating: dataset/test/no/anonymized_569526.jpg
#   inflating: dataset/test/no/anonymized_196860.jpg
#   inflating: dataset/test/no/anonymized_920184.jpg
#   inflating: dataset/test/no/anonymized_1348815.jpg
#   inflating: dataset/test/no/anonymized_225304.jpg
#   inflating: dataset/test/no/anonymized_816099.jpg
#   inflating: dataset/test/no/anonymized_260226.jpg
#   inflating: dataset/test/no/anonymized_1619231.jpg
#   inflating: dataset/test/no/anonymized_1314755.jpg
#   inflating: dataset/test/no/anonymized_1182585.jpg
#   inflating: dataset/test/no/anonymized_656024.jpg
#   inflating: dataset/test/no/anonymized_198917.jpg
#   inflating: dataset/test/no/anonymized_246204.jpg
#   inflating: dataset/test/no/anonymized_324557.jpg
# ...

# %%
from fastai.vision.all import *
import fastai
from wwf.vision.timm import *

# %%
path = Path('dataset/')
trainPath = path/'train'
testPath = path/'test'

# %%
def getDataBlock(presize=512,size=256):
    return DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, 
                 splitter=RandomSplitter(valid_pct=0.2,seed=42),
                 get_y=parent_label,
                 item_tfms = Resize(presize),
                 batch_tfms=[*aug_transforms(size=size, min_scale=0.75), Normalize.from_stats(*imagenet_stats)])

# %%
db512 = getDataBlock()
dls512 = db512.dataloaders(trainPath,bs=64)

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    EarlyStoppingCallback(patience=3),
    SaveModelCallback(fname='resnest101e')
]

# %%
import timm
timm.list_models('*resnest101e*')
# Out:
# ['resnest101e']

# %%
learn = timm_learner(dls512, 'resnest101e',cbs = callbacks,metrics=[accuracy,Precision(),Recall()]).to_fp16()
# Out:
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-resnest/resnest101-22405ba7.pth" to /root/.cache/torch/hub/checkpoints/resnest101-22405ba7.pth

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=5.754399462603033e-05, lr_steep=3.981071586167673e-06)

# %%
learn.fine_tune(10,base_lr=1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.290206</td>
#       <td>0.886508</td>
#       <td>0.519878</td>
#       <td>0.504739</td>
#       <td>0.669811</td>
#       <td>00:51</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.886508047580719.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.300597</td>
# ...

# %%
dbTest = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, 
                 splitter=GrandparentSplitter(valid_name='test'),
                 get_y=parent_label,
                 item_tfms = Resize(512),
                 batch_tfms=[*aug_transforms(size=256, min_scale=0.75), Normalize.from_stats(*imagenet_stats)])
dlsTest = dbTest.dataloaders(path,bs=32)

# %%
learn.dls = dlsTest
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(12,12),dpi=60)

# %%
learn.validate()
# Out:
# Better model found at epoch 0 with valid_loss value: 0.5537897348403931.
# (#4) [0.8303604125976562,0.5537897348403931,0.5767543859649122,0.6045977011494252]

# %%
learn.export(fname='resnet50.pkl')
